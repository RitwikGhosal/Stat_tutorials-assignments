# %%
import random
random_list = []
for i in range(0,20):
    n = random.randint(1,10)
    random_list.append(n)

random_list.sort()
print(random_list)
# Out:
# [1, 1, 2, 2, 2, 3, 4, 4, 4, 6, 6, 6, 6, 7, 7, 7, 8, 8, 9, 9]

# %%
import matplotlib.pyplot as plt

# %%
from scipy.interpolate import interp1d
import numpy as np

# %%
np.fft.fft(random_list)
# Out:
# array([102.        +0.00000000e+00j,  -6.98989828+2.76028648e+01j,
#         -2.19098301+1.40740899e+01j,  -4.72451399+8.52273028e+00j,
#         -3.69098301+5.93085309e+00j,  -7.        +3.00000000e+00j,
#         -3.30901699+5.75933966e+00j,  -4.27548601+1.98384753e+00j,
#         -4.80901699+1.03681323e+00j,  -2.01010172-9.62870129e-02j,
#         -4.        -1.77635684e-15j,  -2.01010172+9.62870129e-02j,
#         -4.80901699-1.03681323e+00j,  -4.27548601-1.98384753e+00j,
#         -3.30901699-5.75933966e+00j,  -7.        -3.00000000e+00j,
#         -3.69098301-5.93085309e+00j,  -4.72451399-8.52273028e+00j,
#         -2.19098301-1.40740899e+01j,  -6.98989828-2.76028648e+01j])

# %%
plt.plot(np.fft.fft(random_list))

# %%
import random
random_list_2 = []
for i in range(0,200):
    n = random.randint(1,10)
    random_list_2.append(n)

random_list.sort()
print(random_list_2)
# Out:
# [3, 2, 3, 7, 9, 7, 2, 6, 6, 5, 1, 6, 9, 9, 7, 10, 6, 10, 4, 8, 5, 3, 2, 7, 8, 5, 10, 6, 10, 6, 4, 2, 10, 9, 3, 7, 1, 7, 9, 3, 10, 8, 6, 10, 8, 3, 2, 1, 3, 10, 7, 6, 8, 3, 1, 8, 1, 7, 3, 5, 4, 1, 8, 7, 7, 4, 10, 5, 7, 10, 1, 2, 7, 8, 10, 2, 6, 2, 6, 9, 9, 5, 7, 8, 1, 1, 5, 6, 8, 1, 10, 7, 2, 9, 4, 3, 1, 5, 6, 7, 2, 9, 6, 1, 10, 4, 1, 5, 4, 3, 10, 8, 3, 3, 5, 3, 6, 8, 7, 4, 2, 6, 2, 3, 2, 1, 2, 5, 5, 6, 5, 8, 7, 8, 5, 5, 6, 5, 2, 5, 7, 4, 9, 7, 3, 6, 10, 8, 8, 2, 9, 10, 2, 3, 10, 6, 9, 5, 5, 4, 10, 7, 9, 6, 5, 5, 10, 3, 3, 3, 1, 8, 3, 9, 9, 10, 5, 7, 4, 4, 3, 2, 6, 5, 4, 4, 1, 1, 7, 2, 5, 7, 6, 5, 2, 7, 8, 8, 9, 9]

# %%
(cA_1, cD_1)  = pywt.dwt(random_list,'db1')
#cA, cD
plt.plot(cA)

# %%
import pywt 
(cA, cD) = pywt.dwt(random_list_2,'db1')
cA
# Out:
# array([ 4.24264069,  8.48528137,  9.89949494,  6.36396103, 12.02081528,
#         9.19238816,  7.77817459, 12.02081528, 12.02081528,  8.48528137,
#         9.89949494,  4.24264069,  3.53553391,  6.36396103,  3.53553391,
#         4.94974747, 12.02081528,  3.53553391, 14.14213562,  3.53553391,
#         4.94974747,  8.48528137,  7.07106781,  7.77817459,  7.77817459,
#        12.02081528,  7.07106781,  7.07106781,  8.48528137,  9.89949494,
#        12.02081528,  4.94974747,  9.19238816,  5.65685425,  6.36396103,
#         9.19238816, 12.72792206,  9.19238816,  9.89949494,  8.48528137,
#        11.3137085 ,  3.53553391,  8.48528137,  8.48528137,  8.48528137,
#         7.77817459,  4.24264069,  4.24264069,  3.53553391,  7.77817459,
#         8.48528137,  6.36396103,  3.53553391,  7.77817459,  6.36396103,
#         6.36396103,  8.48528137,  5.65685425, 12.02081528,  4.94974747,
#         2.12132034,  9.19238816,  9.89949494,  4.24264069,  3.53553391,
#         4.24264069,  7.77817459,  3.53553391,  4.94974747,  7.07106781,
#         7.07106781,  7.77817459, 11.3137085 , 12.72792206,  9.19238816,
#         7.77817459, 12.72792206,  5.65685425,  6.36396103,  7.77817459,
#         7.77817459,  3.53553391,  9.89949494, 12.02081528, 11.3137085 ,
#        14.14213562,  4.94974747,  7.77817459,  4.94974747, 12.02081528,
#         5.65685425, 11.3137085 ,  7.77817459,  7.77817459,  4.94974747,
#         5.65685425,  7.77817459,  5.65685425,  4.94974747,  8.48528137])
